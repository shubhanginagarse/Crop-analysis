# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\data_core.csv")
df.head()
# Out:
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
df.columns
# Out:
# Index(['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type',
#        'Nitrogen', 'Potassium', 'Phosphorous', 'Fertilizer Name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temparature      8000 non-null   float64
#  1   Humidity         8000 non-null   float64
#  2   Moisture         8000 non-null   float64
#  3   Soil Type        8000 non-null   object
#  4   Crop Type        8000 non-null   object
#  5   Nitrogen         8000 non-null   int64
#  6   Potassium        8000 non-null   int64
#  7   Phosphorous      8000 non-null   int64
#  8   Fertilizer Name  8000 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 562.6+ KB

# %%
df.describe()
# Out:
#        Temparature     Humidity     Moisture     Nitrogen    Potassium  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean     30.338895    59.210731    43.580862    18.429125     3.916375
# std       4.478262     8.177366    12.596156    11.852406     5.494807
# min      20.000000    40.020000    20.000000     0.000000     0.000000
# 25%      27.050000    53.277500    33.967500     9.000000     0.000000
# 50%      30.240000    59.110000    42.250000    14.000000     1.000000
# 75%      33.460000    65.082500    52.950000    26.000000     5.000000
# max      40.000000    80.000000    70.000000    46.000000    23.000000
#
#        Phosphorous
# count  8000.000000
# mean     18.512500
# std      13.244113
# min       0.000000
# 25%       8.000000
# 50%      18.000000
# 75%      30.000000
# max      46.000000

# %%
df.columns
# Out:
# Index(['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type',
#        'Nitrogen', 'Potassium', 'Phosphorous', 'Fertilizer Name'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Temparature'],df['Humidity'])
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(10,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type',
#        'Nitrogen', 'Potassium', 'Phosphorous', 'Fertilizer Name'],
#       dtype='object')

# %%
columns_plot=['Temparature', 'Humidity', 'Moisture','Nitrogen', 'Potassium' ]
for i in columns_plot:
   bar_plot(i)
# Out:
# Temparature:
#  Temparature
# 40.00    132
# 29.00     24
# 34.00     17
# 30.00     17
# 26.00     16
#         ...
# 23.04      1
# 20.91      1
# 39.65      1
# 21.98      1
# 39.39      1
# Name: count, Length: 1816, dtype: int64
# Humidity:
#  Humidity
# 60.00    19
# 58.00    17
# 62.00    14
# 54.00    14
# 65.00    13
#          ..
# 43.89     1
# 47.65     1
# 55.33     1
# 62.58     1
# 73.38     1
# Name: count, Length: 3004, dtype: int64
# Moisture:
#  Moisture
# 70.00    160
# 20.00    101
# 30.00     10
# 49.42      9
# 34.00      9
#         ...
# 33.72      1
# 65.08      1
# 26.74      1
# 46.36      1
# 36.03      1
# Name: count, Length: 3723, dtype: int64
# Nitrogen:
#  Nitrogen
# 10    488
# 11    446
# 8     437
# 9     435
# 12    424
# 13    380
# 14    323
# 7     309
# 15    255
# 6     246
# 16    235
# 17    222
# 5     221
# 38    195
# 18    192
# 37    185
# 19    168
# 36    165
# 39    163
# 35    154
# 40    152
# 21    148
# 20    144
# 4     142
# ...

# %%
plt.hist(df['Humidity'])
plt.show()

# %%
plt.hist(df['Temparature'])
plt.show()

# %%
plt.hist(df['Moisture'])
plt.show()

# %%
plt.hist(df['Nitrogen'])
plt.show()

# %%
plt.hist(df['Potassium'])
plt.show()

# %%
plt.hist(df['Phosphorous'])
plt.show()

# %%
df.columns
# Out:
# Index(['Temparature', 'Humidity', 'Moisture', 'Soil Type', 'Crop Type',
#        'Nitrogen', 'Potassium', 'Phosphorous', 'Fertilizer Name'],
#       dtype='object')

# %%
df[['Temparature', 'Humidity']].groupby(['Temparature'],as_index=False).mean().sort_values(by='Humidity',ascending=False)
# Out:
#       Temparature  Humidity
# 1783        39.48    79.620
# 1543        36.69    78.730
# 1703        38.48    77.825
# 1613        37.49    77.600
# 1748        39.00    77.370
# ...           ...       ...
# 377         24.89    41.790
# 9           20.26    41.180
# 64          21.43    41.070
# 21          20.54    40.790
# 104         21.96    40.710
#
# [1816 rows x 2 columns]

# %%
df[['Nitrogen', 'Potassium']].groupby(['Nitrogen'],as_index=False).mean().sort_values(by='Potassium',ascending=False)
# Out:
#     Nitrogen  Potassium
# 1          1  15.566038
# 0          0  15.000000
# 2          2  13.296296
# 3          3  11.049587
# 4          4   9.394366
# 5          5   8.511312
# 6          6   7.918699
# 7          7   7.203883
# 8          8   6.443936
# 9          9   6.091954
# 10        10   5.747951
# 11        11   4.558296
# 12        12   4.554245
# 14        14   4.442724
# 13        13   3.876316
# 15        15   3.858824
# 16        16   2.514894
# 17        17   2.387387
# 18        18   2.020833
# 19        19   1.839286
# 45        46   1.545455
# 44        45   1.113208
# 34        35   1.110390
# 27        27   1.100000
# 25        25   1.090909
# 40        41   1.085106
# 32        33   1.063830
# 38        39   1.024540
# 28        28   1.024390
# 30        31   1.021277
# 35        36   1.018182
# 41        42   1.017241
# 20        20   1.006944
# 36        37   0.994595
# 26        26   0.992481
# 33        34   0.981132
# 39        40   0.973684
# ...

# %%
sns.boxplot(y='Temparature',data=df)
# Out:
# <Axes: ylabel='Temparature'>

# %%
df.isnull().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# dtype: int64

# %%
df
# Out:
#       Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0           26.00     52.00     38.00     Sandy      Maize        37
# 1           29.00     52.00     45.00     Loamy  Sugarcane        12
# 2           34.00     65.00     62.00     Black     Cotton         7
# 3           32.00     62.00     34.00       Red    Tobacco        22
# 4           28.00     54.00     46.00    Clayey      Paddy        35
# ...           ...       ...       ...       ...        ...       ...
# 7995        35.30     59.61     44.25     Loamy  Oil seeds        10
# 7996        39.39     71.67     49.34     Black     Barley        35
# 7997        35.79     67.64     45.04       Red     Barley        41
# 7998        37.78     73.38     36.03     Black    Tobacco        10
# 7999        31.38     48.73     62.27     Loamy    Millets        11
#
#       Potassium  Phosphorous Fertilizer Name
# 0             0            0            Urea
# 1             0           36             DAP
# ...

# %%
df.isna().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# dtype: int64

# %%
df
# Out:
#       Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0           26.00     52.00     38.00     Sandy      Maize        37
# 1           29.00     52.00     45.00     Loamy  Sugarcane        12
# 2           34.00     65.00     62.00     Black     Cotton         7
# 3           32.00     62.00     34.00       Red    Tobacco        22
# 4           28.00     54.00     46.00    Clayey      Paddy        35
# ...           ...       ...       ...       ...        ...       ...
# 7995        35.30     59.61     44.25     Loamy  Oil seeds        10
# 7996        39.39     71.67     49.34     Black     Barley        35
# 7997        35.79     67.64     45.04       Red     Barley        41
# 7998        37.78     73.38     36.03     Black    Tobacco        10
# 7999        31.38     48.73     62.27     Loamy    Millets        11
#
#       Potassium  Phosphorous Fertilizer Name
# 0             0            0            Urea
# 1             0           36             DAP
# ...

# %%
df.drop(labels=['Soil Type','Crop Type','Fertilizer Name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temparature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous
# 0         26.0      52.0      38.0        37          0            0
# 1         29.0      52.0      45.0        12          0           36
# 2         34.0      65.0      62.0         7          9           30
# 3         32.0      62.0      34.0        22          0           20
# 4         28.0      54.0      46.0        35          0            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temparature  8000 non-null   float64
#  1   Humidity     8000 non-null   float64
#  2   Moisture     8000 non-null   float64
#  3   Nitrogen     8000 non-null   int64
#  4   Potassium    8000 non-null   int64
#  5   Phosphorous  8000 non-null   int64
# dtypes: float64(3), int64(3)
# memory usage: 375.1 KB

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()
